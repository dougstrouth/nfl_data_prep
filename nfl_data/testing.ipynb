# %%
import duckdb

# Specify the path to your DuckDB file
db_path = '/Users/dougstrouth/Documents/Code/datasets/sports/NFL/nfl_scores_and_betting/nfl.duckdb'

# Establish a connection to the DuckDB database
con = duckdb.connect(database=db_path, read_only=False)

# Perform some operations
# Example: Query to fetch data from a table named 'my_table'
results = con.execute("SELECT * FROM nfl_stadiums").fetchall()
print(results)

# Close the connection when done
con.close()
# Out:
# [('Acrisure Stadium', 'Pittsburgh, PA', 2001, None, 'outdoor', '100 Art Rooney Ave, Pittsburgh, PA 15212', '15212', 'cold', '65,500', 'Grass', 'USW00094823', 'PITTSBURGH ASOS, PA US', 40.4846, -80.2144, None, 366.7), ('Alamo Dome', 'San Antonio, TX', None, None, 'indoor', '100 Montana St, San Antonio, TX 78203', '78203', 'indoor', '72000', 'FieldTurf', None, None, 29.416944, -98.478889, 0.0, None), ('Allegiant Stadium', 'Paradise, NV', 2020, None, 'indoor', None, None, 'indoor', '65000', 'Grass', None, None, 36.09075, -115.183722, 0.0, None), ('Allianz Arena', 'Munich, Germany', None, None, 'outdoor', None, None, 'moderate', '75,024', 'Grass', None, None, None, None, None, None), ('Alltel Stadium', 'Jacksonville, FL', None, None, None, None, None, 'warm', None, None, None, None, 30.323889, -81.6375, 16.7, 6.1), ('Alumni Stadium', 'Chestnut Hill, MA', None, None, 'outdoor', 'Perimeter Rd, Chestnut Hill, MA 02467', '2467', 'cold', None, 'Grass', None, None, None, None, None, None), ('A
# ...
